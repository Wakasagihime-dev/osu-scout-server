# %%
import os
from pymongo import MongoClient
import dotenv
from bson.json_util import dumps

dotenv.load_dotenv("./.env")

client = MongoClient(os.getenv("MONGO_CONN_STR"))

col = client["db_2026_06_02"]["map-stats"]

# %%
res = col.find()
dumps(next(res, None))
# Out:
# '{"_id": {"$oid": "6a3fefdd674643095b16f13f"}, "avg_num_jumps": 28.5, "avg_stream_length": 0, "avg_burst_length": 0, "avg_irr_length": 1.0, "overall_irr_percent": 0.8333333333333334, "num_jump_secs": 4, "num_stream_secs": 0, "num_burst_secs": 0, "num_irr_secs": 1, "is_regular": true, "is_jump": true, "stream-density": 0.03333333333333333, "stream-spacing": 0.0, "ar": 0.0, "bpm": 140, "id": 100, "beatmapset_id": 100, "title": "Fall Memories", "artist": "Phantasma", "creator": "Kylecito", "star_rating": 2.2560036523880056, "pp_100": 29.244134106931472, "pp_95": 11.003974620841445, "tags": "", "max_combo": 222, "bg_url": "https://assets.ppy.sh/beatmaps/31/covers/cover.jpg", "url": "https://osu.ppy.sh/beatmapsets/31#osu/100", "version": "Hard", "_fpath": "2026_06_02_osu_files\\\\100.osu"}'

# %%
a = {"cat": 1}
b = {"dog": 3}

a.update(b)

a
# Out:
# {'cat': 1, 'dog': 3}
